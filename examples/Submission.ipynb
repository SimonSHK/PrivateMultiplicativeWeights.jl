# %%
using Pkg
Pkg.activate(".")
Pkg.instantiate()

using PrivateMultiplicativeWeights
Pkg.add("Distributions")
Pkg.add("Printf")
Pkg.add("Hadamard")
Pkg.add("LinearAlgebra")
Pkg.add("Random")
Pkg.add("IterTools")
Pkg.add("Statistics")
Pkg.add("Distributed")
Pkg.add("PyPlot")
Pkg.add("PyCall")

include("../examples/marginals.jl")

mw = marginals()
print(typeof(mw))
# Out:
#   Activating new project at `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples`
#    Resolving package versions...
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Project.toml`
#   [31c24e10] + Distributions v0.25.109
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [49dc2e85] + Calculus v0.5.1
#   [34da2185] + Compat v4.15.0
#   [9a962f9c] + DataAPI v1.16.0
#   [864edb3b] + DataStructures v0.18.20
#   [31c24e10] + Distributions v0.25.109
#   [ffbed154] + DocStringExtensions v0.9.3
#   [fa6b7ba4] + DualNumbers v0.6.8
#   [1a297f60] + FillArrays v1.11.0
#   [34004b35] + HypergeometricFunctions v0.3.23
#   [92d709cd] + IrrationalConstants v0.2.2
#   [692b3bcd] + JLLWrappers v1.5.0
#   [2ab3a3ac] + LogExpFunctions v0.3.28
#   [e1d29d7a] + Missings v1.2.0
#   [77ba4419] + NaNMath v1.0.2
#   [bac558e1] + OrderedCollections v1.6.3
#   [90014a1f] + PDMats v0.11.31
#   [21216c6a] + Preferences v1.4.3
#   [43287f4e] + PtrArrays v1.2.0
#   [1fd47b50] + QuadGK v2.9.4
#   [189a3867] + Reexport v1.2.2
#   [79098fc4] + Rmath v0.7.1
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [276daf66] + SpecialFunctions v2.4.0
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.3
#   [4c63d2b9] + StatsFuns v1.3.1
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [f50d1b31] + Rmath_jll v0.4.2+0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b77e0a4c] + InteractiveUtils
#   [b27032c2] + LibCURL v0.6.4
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [ca575930] + NetworkOptions v1.2.0
#   [44cfe95a] + Pkg v1.10.0
#   [de0858da] + Printf
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays v1.10.0
#   [10745b16] + Statistics v1.10.0
#   [4607b0f0] + SuiteSparse
#   [fa267f1f] + TOML v1.0.3
#   [a4e569a6] + Tar v1.10.0
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [deac9b47] + LibCURL_jll v8.4.0+0
#   [e37daf67] + LibGit2_jll v1.6.4+0
#   [29816b5a] + LibSSH2_jll v1.11.0+1
#   [c8ffd9c3] + MbedTLS_jll v2.28.2+1
#   [14a3606d] + MozillaCACerts_jll v2023.1.10
#   [4536629a] + OpenBLAS_jll v0.3.23+4
#   [05823500] + OpenLibm_jll v0.8.1+2
#   [bea87d4a] + SuiteSparse_jll v7.2.1+1
#   [83775a58] + Zlib_jll v1.2.13+1
#   [8e850b90] + libblastrampoline_jll v5.8.0+1
#   [8e850ede] + nghttp2_jll v1.52.0+1
#   [3f19e933] + p7zip_jll v17.4.0+2
#    Resolving package versions...
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Project.toml`
#   [de0858da] + Printf
#   No Changes to `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Manifest.toml`
#    Resolving package versions...
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Project.toml`
#   [4a05ff16] + Hadamard v1.5.0
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [7a1cc6ca] + FFTW v1.8.0
#   [4a05ff16] + Hadamard v1.5.0
#   [f5851436] + FFTW_jll v3.3.10+0
#   [1d5cc7b8] + IntelOpenMP_jll v2024.1.0+0
#   [856f044c] + MKL_jll v2024.1.0+0
#   [1317d2d5] + oneTBB_jll v2021.12.0+0
#   [4af54fe1] + LazyArtifacts
#    Resolving package versions...
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Project.toml`
#   [37e2e46d] + LinearAlgebra
#   No Changes to `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Manifest.toml`
#    Resolving package versions...
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Project.toml`
#   [9a3f8284] + Random
#   No Changes to `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Manifest.toml`
#    Resolving package versions...
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Project.toml`
#   [c8e1da08] + IterTools v1.10.0
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Manifest.toml`
#   [c8e1da08] + IterTools v1.10.0
#    Resolving package versions...
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Project.toml`
#   [10745b16] + Statistics v1.10.0
#   No Changes to `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Manifest.toml`
#    Resolving package versions...
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Project.toml`
#   [8ba89e20] + Distributed
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Manifest.toml`
#   [8ba89e20] + Distributed
#    Resolving package versions...
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Project.toml`
#   [d330b81b] + PyPlot v2.11.2
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Manifest.toml`
#   [3da002f7] + ColorTypes v0.11.5
#   [5ae59095] + Colors v0.12.11
#   [8f4d0f93] + Conda v1.10.0
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [682c06a0] + JSON v0.21.4
#   [b964fa9f] + LaTeXStrings v1.3.1
#   [1914dd2f] + MacroTools v0.5.13
#   [69de0a69] + Parsers v2.8.1
#   [aea7be01] + PrecompileTools v1.2.1
#   [438e738f] + PyCall v1.96.4
#   [d330b81b] + PyPlot v2.11.2
#   [81def892] + VersionParsing v1.3.0
#   [a63ad114] + Mmap
#   [8dfed614] + Test
#    Resolving package versions...
#     Updating `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Project.toml`
#   [438e738f] + PyCall v1.96.4
#   No Changes to `~/Documents/Grad School/Classes/Spring 2024/DP/final_project/PMW_fork/PrivateMultiplicativeWeights.jl/examples/Manifest.toml`
# Iter.	 Mean sq err	 time (sec)
# 0	 0.002		 0.027
# itr: 1	 mean_error: 0.002		 0.210
# itr: 1	 max_error: 0.512		 0.210
# itr: 2	 mean_error: 0.001		 0.151
# itr: 2	 max_error: 0.494		 0.151
# itr: 3	 mean_error: 0.001		 0.238
# itr: 3	 max_error: 0.598		 0.238
# itr: 4	 mean_error: 0.001		 0.283
# itr: 4	 max_error: 0.114		 0.283
# itr: 5	 mean_error: 0.001		 0.344
# itr: 5	 max_error: 0.094		 0.344
# itr: 6	 mean_error: 0.001		 0.402
# itr: 6	 max_error: 0.086		 0.402
# itr: 7	 mean_error: 0.001		 0.486
# itr: 7	 max_error: 0.086		 0.486
# itr: 8	 mean_error: 0.001		 0.541
# itr: 8	 max_error: 0.086		 0.541
# itr: 9	 mean_error: 0.001		 0.596
# itr: 9	 max_error: 0.086		 0.596
# itr: 10	 mean_error: 0.001		 0.666
# itr: 10	 max_error: 0.086		 0.666
# Iter.	 Mean sq err	 time (sec)
# 0	 0.002		 0.016
# itr: 1	 mean_error: 0.002		 0.083
# itr: 1	 max_error: 0.508		 0.083
# itr: 2	 mean_error: 0.001		 0.149
# itr: 2	 max_error: 0.498		 0.149
# itr: 3	 mean_error: 0.001		 0.212
# itr: 3	 max_error: 0.608		 0.212
# itr: 4	 mean_error: 0.001		 0.288
# itr: 4	 max_error: 0.096		 0.288
# itr: 5	 mean_error: 0.001		 0.344
# itr: 5	 max_error: 0.096		 0.344
# itr: 6	 mean_error: 0.001		 0.406
# itr: 6	 max_error: 0.096		 0.406
# itr: 7	 mean_error: 0.001		 0.475
# itr: 7	 max_error: 0.094		 0.475
# itr: 8	 mean_error: 0.001		 0.536
# itr: 8	 max_error: 0.094		 0.536
# itr: 9	 mean_error: 0.001		 0.599
# itr: 9	 max_error: 0.094		 0.599
# itr: 10	 mean_error: 0.001		 0.652
# itr: 10	 max_error: 0.094		 0.652
# PrivateMultiplicativeWeights.MWState
